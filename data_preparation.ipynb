# %% [markdown]
# # DATA PREPARATION

# %%
# Import libraries
import numpy as np
import pandas as pd
import spotipy
import spotipy.util as util

# %%
# Authentication details
my_username = "oso41"
chosen_scope = "user-library-read"
my_client_id = ""
my_client_secret = ""

# %%
# Token creation
token = util.prompt_for_user_token(username=my_username,
                                   scope=chosen_scope,
                                   client_id=my_client_id,
                                   client_secret=my_client_secret,
                                   redirect_uri="http://127.0.0.1/")

# %%
# Spotipy object
sp = spotipy.Spotify(auth=token)

# %% [markdown]
# ### CREATION OF GOOD TRACKS DATAFRAME

# %%
# Create empty lists where results will be stored
artist_name = []
track_name = []
popularity = []
track_id = []

# %%
# Obtain data (artist name, track name, track id, popularity) from playlist containing liked songs
for i in range(0,8000,100):
    results = sp.user_playlist_tracks(my_username,playlist_id="113sBEwMtYziAis9d3CmzJ",limit=100, offset=i)
    for i, t in enumerate(results['items']):
        artist_name.append(t['track']['artists'][0]['name'])
        track_name.append(t['track']['name'])
        track_id.append(t['track']['id'])
        popularity.append(t['track']['popularity'])

# %%
# Create dataframe of tracks
df_tracks = pd.DataFrame([artist_name,track_name,track_id,popularity]).transpose()
df_tracks.columns = ['artist_name','track_name','track_id','popularity']

# %%
df_tracks.head()
# Out:
#    artist_name                                       track_name  \
# 0  Kyle Landry                       Howl's Moving Castle Theme
# 1  Kyle Landry          Shigatsu - Otouto Mitai Na Sonzai Piano
# 2  Kyle Landry  Passion (From "Kingdom Hearts II") [Piano Solo]
# 3  Kyle Landry                                  Dango Daikazoku
# 4  Kyle Landry                        Interstellar - First Step
#
#                  track_id popularity
# 0  3JTjiMAPVMfwjzPiG5R3hK         54
# 1  5tr1bCo0XRU3ZciXahlTKm         47
# 2  2xFBrGSZ4mSURd8p5IU4ed         47
# 3  7c6mInVLlpnaYD55R72FDX         45
# 4  0kznmyiS92b9v1rkn9WDqV         41

# %%
# There are some tracks that are repeated (with the the same track name and track id). Therefore, the duplicates have 
# been removed using the drop_duplicated method with the subset of the name of the artist and of the track
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
# Drop NaN values
df_tracks.dropna(inplace=True)

# %%
# Create new column with a value of 1 since for all the songs of this dataframe (since I liked all these songs)
df_tracks['like'] = 1

# %%
df_tracks.head()
# Out:
#    artist_name                                       track_name  \
# 0  Kyle Landry                       Howl's Moving Castle Theme
# 1  Kyle Landry          Shigatsu - Otouto Mitai Na Sonzai Piano
# 2  Kyle Landry  Passion (From "Kingdom Hearts II") [Piano Solo]
# 3  Kyle Landry                                  Dango Daikazoku
# 4  Kyle Landry                        Interstellar - First Step
#
#                  track_id popularity  like
# 0  3JTjiMAPVMfwjzPiG5R3hK         54     1
# 1  5tr1bCo0XRU3ZciXahlTKm         47     1
# 2  2xFBrGSZ4mSURd8p5IU4ed         47     1
# 3  7c6mInVLlpnaYD55R72FDX         45     1
# 4  0kznmyiS92b9v1rkn9WDqV         41     1

# %%
# Create empty list to store songs features
rows = []

# Retrieve audio features for every track
for i in range(0,len(df_tracks['track_id']),50):
    feature_results = sp.audio_features(df_tracks['track_id'][i:i+50])
    for i, t in enumerate(feature_results):
        rows.append(t)

# %%
# Create dataframe from previously retrieved daa
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')

# %%
df_audio_features.head()
# Out:
#    acousticness                                       analysis_url  \
# 0         0.940  https://api.spotify.com/v1/audio-analysis/3JTj...
# 1         0.967  https://api.spotify.com/v1/audio-analysis/5tr1...
# 2         0.964  https://api.spotify.com/v1/audio-analysis/2xFB...
# 3         0.976  https://api.spotify.com/v1/audio-analysis/7c6m...
# 4         0.961  https://api.spotify.com/v1/audio-analysis/0kzn...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.322       350348  0.1440  3JTjiMAPVMfwjzPiG5R3hK
# 1         0.368       302336  0.1240  5tr1bCo0XRU3ZciXahlTKm
# 2         0.406       274656  0.1300  2xFBrGSZ4mSURd8p5IU4ed
# 3         0.384       310974  0.0400  7c6mInVLlpnaYD55R72FDX
# 4         0.232       508622  0.0651  0kznmyiS92b9v1rkn9WDqV
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.917    7    0.0744   -17.448     0       0.0384  142.818
# 1             0.803    3    0.1820   -21.851     1       0.0513  138.910
# 2             0.870    1    0.0964   -20.320     0       0.0515  116.005
# 3             0.896    8    0.0943   -23.524     1       0.0357   95.854
# 4             0.930    9    0.0607   -21.866     0       0.0387   74.750
#
#    time_signature                                         track_href  \
# 0               3  https://api.spotify.com/v1/tracks/3JTjiMAPVMfw...
# 1               4  https://api.spotify.com/v1/tracks/5tr1bCo0XRU3...
# 2               4  https://api.spotify.com/v1/tracks/2xFBrGSZ4mSU...
# 3               4  https://api.spotify.com/v1/tracks/7c6mInVLlpna...
# 4               3  https://api.spotify.com/v1/tracks/0kznmyiS92b9...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:3JTjiMAPVMfwjzPiG5R3hK   0.0471
# 1  audio_features  spotify:track:5tr1bCo0XRU3ZciXahlTKm   0.1040
# 2  audio_features  spotify:track:2xFBrGSZ4mSURd8p5IU4ed   0.0975
# 3  audio_features  spotify:track:7c6mInVLlpnaYD55R72FDX   0.1000
# 4  audio_features  spotify:track:0kznmyiS92b9v1rkn9WDqV   0.0372

# %%
# Drop useless columns containing useless information
df_audio_features.drop(['analysis_url','track_href','type','uri'],axis=1,inplace=True)

# %%
df_audio_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0         0.940         0.322       350348  0.1440  3JTjiMAPVMfwjzPiG5R3hK
# 1         0.967         0.368       302336  0.1240  5tr1bCo0XRU3ZciXahlTKm
# 2         0.964         0.406       274656  0.1300  2xFBrGSZ4mSURd8p5IU4ed
# 3         0.976         0.384       310974  0.0400  7c6mInVLlpnaYD55R72FDX
# 4         0.961         0.232       508622  0.0651  0kznmyiS92b9v1rkn9WDqV
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.917    7    0.0744   -17.448     0       0.0384  142.818
# 1             0.803    3    0.1820   -21.851     1       0.0513  138.910
# 2             0.870    1    0.0964   -20.320     0       0.0515  116.005
# 3             0.896    8    0.0943   -23.524     1       0.0357   95.854
# 4             0.930    9    0.0607   -21.866     0       0.0387   74.750
#
#    time_signature  valence
# 0               3   0.0471
# 1               4   0.1040
# 2               4   0.0975
# 3               4   0.1000
# 4               3   0.0372

# %%
# Change 'id' name to 'track_id' in order to match with previous dataframe (prepare for merging)
df_audio_features.rename(columns={'id':'track_id'},inplace=True)

# %%
# Merge both dataframes
df = pd.merge(df_tracks,df_audio_features,on='track_id',how='inner')

# %%
df.head()
# Out:
#    artist_name                                       track_name  \
# 0  Kyle Landry                       Howl's Moving Castle Theme
# 1  Kyle Landry          Shigatsu - Otouto Mitai Na Sonzai Piano
# 2  Kyle Landry  Passion (From "Kingdom Hearts II") [Piano Solo]
# 3  Kyle Landry                                  Dango Daikazoku
# 4  Kyle Landry                        Interstellar - First Step
#
#                  track_id popularity  like  acousticness  danceability  \
# 0  3JTjiMAPVMfwjzPiG5R3hK         54     1         0.940         0.322
# 1  5tr1bCo0XRU3ZciXahlTKm         47     1         0.967         0.368
# 2  2xFBrGSZ4mSURd8p5IU4ed         47     1         0.964         0.406
# 3  7c6mInVLlpnaYD55R72FDX         45     1         0.976         0.384
# 4  0kznmyiS92b9v1rkn9WDqV         41     1         0.961         0.232
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       350348  0.1440             0.917    7    0.0744   -17.448     0
# 1       302336  0.1240             0.803    3    0.1820   -21.851     1
# 2       274656  0.1300             0.870    1    0.0964   -20.320     0
# 3       310974  0.0400             0.896    8    0.0943   -23.524     1
# 4       508622  0.0651             0.930    9    0.0607   -21.866     0
#
#    speechiness    tempo  time_signature  valence
# 0       0.0384  142.818               3   0.0471
# 1       0.0513  138.910               4   0.1040
# 2       0.0515  116.005               4   0.0975
# 3       0.0357   95.854               4   0.1000
# 4       0.0387   74.750               3   0.0372

# %%
df.to_csv('good_tracks.csv')

# %% [markdown]
# ### CREATION OF BAD TRACKS DATAFRAME

# %%
# REPEAT PREVIOUS PROCESS 

artist_name = []
track_name = []
popularity = []
track_id = []

# %%
for i in range(0,2000,100):
    results = sp.user_playlist_tracks(my_username,playlist_id="2POKTRd37hqKGQS7hvV9Qo",limit=100, offset=i)
    for i, t in enumerate(results['items']):
        artist_name.append(t['track']['artists'][0]['name'])
        track_name.append(t['track']['name'])
        track_id.append(t['track']['id'])
        popularity.append(t['track']['popularity'])

# %%
df_bad_tracks = pd.DataFrame([artist_name,track_name,track_id,popularity]).transpose()

# %%
df_bad_tracks.columns = ['artist_name','track_name','track_id','popularity']

# %%
df_bad_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
df_bad_tracks.dropna(inplace=True)

# %%
# This time we assign a 0 to all songs since I didn't like them
df_bad_tracks['like'] = 0

# %%
df_bad_tracks.head()
# Out:
#      artist_name                       track_name                track_id  \
# 0          Rkomi  Mon Cheri (feat. Sfera Ebbasta)  66UkKyxN5YbJl9z7YamQOR
# 1      Priestess              Chef (feat. Madman)  4QSLqqTFzsXR8MWfJeI3zq
# 2     Capo Plaza            Billets (feat. Ninho)  2aD5ESGyEhXnXdoOsZvsR0
# 3  Sfera Ebbasta                     Mademoiselle  2aPnpV1hT7l3eP10uSGK6c
# 4     MamboLosco                            BINGO  2fXOb3Dr8di7hbcKFbYNPt
#
#   popularity  like
# 0         76     0
# 1         58     0
# 2         73     0
# 3         81     0
# 4         69     0

# %%
rows = []

for i in range(0,len(df_bad_tracks['track_id']),50):
    feature_results = sp.audio_features(df_bad_tracks['track_id'][i:i+50])
    for i, t in enumerate(feature_results):
        rows.append(t)

# %%
df_bad_audio_features = pd.DataFrame.from_dict(rows,orient='columns')

# %%
df_bad_audio_features.head()
# Out:
#    acousticness                                       analysis_url  \
# 0        0.3160  https://api.spotify.com/v1/audio-analysis/66Uk...
# 1        0.2770  https://api.spotify.com/v1/audio-analysis/4QSL...
# 2        0.2980  https://api.spotify.com/v1/audio-analysis/2aD5...
# 3        0.0671  https://api.spotify.com/v1/audio-analysis/2aPn...
# 4        0.1580  https://api.spotify.com/v1/audio-analysis/2fXO...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.887       181867   0.667  66UkKyxN5YbJl9z7YamQOR
# 1         0.944       176239   0.661  4QSLqqTFzsXR8MWfJeI3zq
# 2         0.732       198537   0.791  2aD5ESGyEhXnXdoOsZvsR0
# 3         0.794       189344   0.702  2aPnpV1hT7l3eP10uSGK6c
# 4         0.796       150444   0.643  2fXOb3Dr8di7hbcKFbYNPt
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    6    0.1190    -5.681     0       0.0484  130.032
# 1               0.0    4    0.2840    -5.643     0       0.0556  133.114
# 2               0.0    1    0.1750    -5.642     1       0.1910  123.101
# 3               0.0    6    0.1550    -5.656     0       0.0346  121.938
# 4               0.0    2    0.0561    -5.235     0       0.0354  128.057
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/66UkKyxN5YbJ...
# 1               4  https://api.spotify.com/v1/tracks/4QSLqqTFzsXR...
# 2               4  https://api.spotify.com/v1/tracks/2aD5ESGyEhXn...
# 3               4  https://api.spotify.com/v1/tracks/2aPnpV1hT7l3...
# 4               4  https://api.spotify.com/v1/tracks/2fXOb3Dr8di7...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:66UkKyxN5YbJl9z7YamQOR    0.493
# 1  audio_features  spotify:track:4QSLqqTFzsXR8MWfJeI3zq    0.963
# 2  audio_features  spotify:track:2aD5ESGyEhXnXdoOsZvsR0    0.609
# 3  audio_features  spotify:track:2aPnpV1hT7l3eP10uSGK6c    0.535
# 4  audio_features  spotify:track:2fXOb3Dr8di7hbcKFbYNPt    0.609

# %%
df_bad_audio_features.drop(['analysis_url','track_href','type','uri'],axis=1,inplace=True)

# %%
df_bad_audio_features.rename(columns={'id':'track_id'},inplace=True)

# %%
df_bad = pd.merge(df_bad_tracks,df_bad_audio_features,on='track_id',how='inner')

# %%
df_bad.head()
# Out:
#      artist_name                       track_name                track_id  \
# 0          Rkomi  Mon Cheri (feat. Sfera Ebbasta)  66UkKyxN5YbJl9z7YamQOR
# 1      Priestess              Chef (feat. Madman)  4QSLqqTFzsXR8MWfJeI3zq
# 2     Capo Plaza            Billets (feat. Ninho)  2aD5ESGyEhXnXdoOsZvsR0
# 3  Sfera Ebbasta                     Mademoiselle  2aPnpV1hT7l3eP10uSGK6c
# 4     MamboLosco                            BINGO  2fXOb3Dr8di7hbcKFbYNPt
#
#   popularity  like  acousticness  danceability  duration_ms  energy  \
# 0         76     0        0.3160         0.887       181867   0.667
# 1         58     0        0.2770         0.944       176239   0.661
# 2         73     0        0.2980         0.732       198537   0.791
# 3         81     0        0.0671         0.794       189344   0.702
# 4         69     0        0.1580         0.796       150444   0.643
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    6    0.1190    -5.681     0       0.0484  130.032
# 1               0.0    4    0.2840    -5.643     0       0.0556  133.114
# 2               0.0    1    0.1750    -5.642     1       0.1910  123.101
# 3               0.0    6    0.1550    -5.656     0       0.0346  121.938
# 4               0.0    2    0.0561    -5.235     0       0.0354  128.057
#
#    time_signature  valence
# 0               4    0.493
# 1               4    0.963
# 2               4    0.609
# 3               4    0.535
# 4               4    0.609

# %%
df_bad.to_csv('bad_tracks.csv')
